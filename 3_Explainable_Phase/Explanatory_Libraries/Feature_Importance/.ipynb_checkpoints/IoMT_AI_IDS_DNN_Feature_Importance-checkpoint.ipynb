# %% [markdown]
# # Feature Importance

# %% [markdown]
# ## Data Preparation

# %%
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %% [markdown]
# Load Previous Trained Model

# %%
from tensorflow.keras.models import load_model

model = load_model('../../../2_Modeling_Phase/Saved-Models/IoMT_AI_IDS_DNN-Deep-Neural-Network_Model.h5')
# Out:
# 2024-03-14 11:59:06.598533: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-14 11:59:06.624933: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-14 11:59:06.624955: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-14 11:59:06.625602: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-14 11:59:06.629984: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-14 11:59:07.196248: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/ivoafonsobispo/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py:85: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-03-14 11:59:07.463433: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-14 11:59:07.486417: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %% [markdown]
# Load Train Dataset

# %%
df_train = pd.read_csv("../../../0_Datasets/IoMT_AI_IDS/Flows/train.csv")

# %% [markdown]
# Load Test Dataset

# %%
df_test = pd.read_csv("../../../0_Datasets/IoMT_AI_IDS/Flows/test.csv")

# %%
display(df_train)
# Out:
#        fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  \
# 0         -0.674434     -0.621972          -0.450908          -0.746950
# 1         -0.722124     -0.725850          -0.546365          -0.746950
# 2         -0.674434     -0.621972          -0.450908          -0.746950
# 3         -0.674434     -0.621972          -0.450908          -0.746950
# 4         -0.865193     -0.933607          -0.928195          -0.746950
# ...             ...           ...                ...                ...
# 60883     -0.674434     -0.621972          -0.450908          -0.746950
# 60884      1.471606      1.455598           1.458239           1.467491
# 60885     -0.722124     -0.829729          -0.832738          -0.658372
# 60886     -0.674434     -0.621972          -0.450908          -0.746950
# 60887     -0.579055     -0.414215          -0.641823          -0.658372
#
#        fwd_pkts_per_sec  bwd_pkts_per_sec  flow_pkts_per_sec  down_up_ratio  \
# 0             -0.572718         -0.467121          -0.530517       0.232052
# 1             -0.572239         -0.466783          -0.530104       0.232052
# 2             -0.572705         -0.467112          -0.530505       0.232052
# 3             -0.572649         -0.467072          -0.530456       0.232052
# 4             -0.054334          0.273648           0.143245       2.515023
# ...                 ...               ...                ...            ...
# 60883         -0.572671         -0.467088          -0.530476       0.232052
# 60884         -0.477501         -0.437955          -0.471839      -0.909433
# 60885          1.287170          0.515371           0.866938      -0.338691
# 60886         -0.572663         -0.467082          -0.530469       0.232052
# 60887          0.567624          0.337880           0.449646       0.232052
#
#        fwd_header_size_tot  fwd_header_size_min  ...  flow_pkts_payload.max  \
# 0                -0.680179             0.002967  ...              -0.517239
# 1                -0.727991             0.002967  ...              -0.517239
# 2                -0.680179             0.002967  ...              -0.517239
# 3                -0.680179             0.002967  ...              -0.517239
# 4                -0.871428             0.002967  ...              -0.519508
# ...                    ...                  ...  ...                    ...
# 60883            -0.680179             0.002967  ...              -0.517239
# 60884             1.471377             0.002967  ...              -0.448033
# 60885            -0.716038             0.002967  ...              -0.392819
# 60886            -0.680179             0.002967  ...              -0.517239
# 60887            -0.572601             0.002967  ...               2.218502
#
#        flow_pkts_payload.tot  flow_pkts_payload.avg  flow_pkts_payload.std  \
# 0                  -0.823663              -0.557857              -0.528041
# 1                  -0.824912              -0.557857              -0.527991
# 2                  -0.823663              -0.557857              -0.528041
# 3                  -0.823663              -0.557857              -0.528041
# 4                  -0.829911              -0.565532              -0.531550
# ...                      ...                    ...                    ...
# 60883              -0.823663              -0.557857              -0.528041
# 60884               0.111859              -0.411279              -0.439380
# 60885              -0.695789              -0.330161              -0.356992
# 60886              -0.823663              -0.557857              -0.528041
# 60887               1.958328               1.881011               1.876969
#
#        fwd_subflow_pkts  bwd_subflow_pkts  fwd_subflow_bytes  \
# 0             -0.792487         -0.886108          -0.805688
# 1             -0.792487         -0.886108          -0.805688
# 2             -0.792487         -0.886108          -0.805688
# 3             -0.792487         -0.886108          -0.805688
# 4             -0.792487         -0.788171          -0.806943
# ...                 ...               ...                ...
# 60883         -0.792487         -0.886108          -0.805688
# 60884          1.486861          1.464372           0.118161
# 60885         -0.652935         -0.690234          -0.736859
# 60886         -0.792487         -0.886108          -0.805688
# 60887         -0.513383         -0.298488           1.962091
#
#        bwd_subflow_bytes       traffic  is_attack
# 0              -0.992819        normal          0
# 1              -0.992819        normal          0
# 2              -0.992819        normal          0
# 3              -0.992819        normal          0
# 4              -0.992819     rudeadyet          1
# ...                  ...           ...        ...
# 60883          -0.992819        normal          0
# 60884           0.190744   mqttmalaria          1
# 60885           2.664391     rudeadyet          1
# 60886          -0.992819        normal          0
# 60887           0.806197  apachekiller          1
#
# [60888 rows x 35 columns]

# %%
display(df_test)
# Out:
#        fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  \
# 0         -0.817503     -0.933607          -0.737280          -0.746950
# 1         -0.579055     -0.414215          -0.641823          -0.658372
# 2         -0.674434     -0.621972          -0.450908          -0.746950
# 3         -0.674434     -0.621972          -0.450908          -0.746950
# 4         -0.674434     -0.621972          -0.450908          -0.746950
# ...             ...           ...                ...                ...
# 20291     -0.674434     -0.621972          -0.450908          -0.746950
# 20292     -0.674434     -0.621972          -0.450908          -0.746950
# 20293     -0.579055     -0.414215          -0.641823          -0.658372
# 20294     -0.626744     -0.518094          -0.737280          -0.658372
# 20295      1.376226      1.351719           1.362782           1.378913
#
#        fwd_pkts_per_sec  bwd_pkts_per_sec  flow_pkts_per_sec  down_up_ratio  \
# 0             -0.482514         -0.403444          -0.452983       0.232052
# 1              0.552561          0.327246           0.436698       0.232052
# 2             -0.572623         -0.467054          -0.530434       0.232052
# 3             -0.572631         -0.467059          -0.530441       0.232052
# 4             -0.572633         -0.467061          -0.530443       0.232052
# ...                 ...               ...                ...            ...
# 20291         -0.572961         -0.467292          -0.530725       0.232052
# 20292         -0.572624         -0.467055          -0.530436       0.232052
# 20293          0.564715          0.335826           0.447145       0.232052
# 20294          0.407513          0.224853           0.312025       0.232052
# 20295         -0.478297         -0.438235          -0.472352      -0.909433
#
#        fwd_header_size_tot  fwd_header_size_min  ...  flow_pkts_payload.max  \
# 0                -0.823616             0.002967  ...              -0.509298
# 1                -0.572601             0.002967  ...               2.218502
# 2                -0.680179             0.002967  ...              -0.517239
# 3                -0.680179             0.002967  ...              -0.517239
# 4                -0.680179             0.002967  ...              -0.517239
# ...                    ...                  ...  ...                    ...
# 20291            -0.680179             0.002967  ...              -0.517239
# 20292            -0.680179             0.002967  ...              -0.517239
# 20293            -0.572601             0.002967  ...               2.218502
# 20294            -0.620413             0.002967  ...               2.218502
# 20295             1.375752             0.002967  ...              -0.449545
#
#        flow_pkts_payload.tot  flow_pkts_payload.avg  flow_pkts_payload.std  \
# 0                  -0.818664              -0.530994              -0.514251
# 1                   1.967492               1.889052               1.878208
# 2                  -0.823663              -0.557857              -0.528041
# 3                  -0.823663              -0.557857              -0.528041
# 4                  -0.823663              -0.557857              -0.528041
# ...                      ...                    ...                    ...
# 20291              -0.823663              -0.557857              -0.528041
# 20292              -0.823663              -0.557857              -0.528041
# 20293               1.949165               1.872970               1.893964
# 20294               1.936669               2.266596               2.316445
# 20295               0.080412              -0.410217              -0.438718
#
#        fwd_subflow_pkts  bwd_subflow_pkts  fwd_subflow_bytes  \
# 0             -0.745970         -0.788171          -0.795646
# 1             -0.513383         -0.298488           1.971296
# 2             -0.792487         -0.886108          -0.805688
# 3             -0.792487         -0.886108          -0.805688
# 4             -0.792487         -0.886108          -0.805688
# ...                 ...               ...                ...
# 20291         -0.792487         -0.886108          -0.805688
# 20292         -0.792487         -0.886108          -0.805688
# 20293         -0.513383         -0.298488           1.952886
# 20294         -0.559901         -0.396424           1.940334
# 20295          1.393826          1.366436           0.087407
#
#        bwd_subflow_bytes       traffic  is_attack
# 0              -0.992819     slowloris          1
# 1               0.806197  apachekiller          1
# 2              -0.992819        normal          0
# 3              -0.992819        normal          0
# 4              -0.992819        normal          0
# ...                  ...           ...        ...
# 20291          -0.992819        normal          0
# 20292          -0.992819     slowloris          1
# 20293           0.806197  apachekiller          1
# 20294           0.806197  apachekiller          1
# 20295           0.143401   mqttmalaria          1
#
# [20296 rows x 35 columns]

# %% [markdown]
# -----
# ## Train and Test Datasets

# %% [markdown]
# Drop Multiclass Column

# %%
df_train = df_train.drop('traffic', axis=1)
df_test = df_test.drop('traffic', axis=1)

# %% [markdown]
# Excluding the target variable

# %%
X_columns = df_train.columns.drop('is_attack')

# %% [markdown]
# Create a feature matrix X by selecting only the columns specified in X_columns. Then convert the selected data into a NumPy array.

# %%
X = df_train[X_columns].values

# %% [markdown]
# Creates a target variable y containing the target variable

# %%
y = df_train["is_attack"].values

# %% [markdown]
# Split into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

# %% [markdown]
# Get Features Names and Class Names

# %%
feature_names = list(X_columns)
class_names = ["Normal", "Malicious"]
response_dict = {0: 'Normal', 1: 'Malicious'}

# %% [markdown]
# Generate Prediction

# %%
pred = model.predict(X_test)
# Out:
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step

# %% [markdown]
# Labeled Df's

# %%
X_test_labeled = pd.DataFrame(X_test, columns=feature_names)
X_train_labeled = pd.DataFrame(X_train, columns=feature_names)

# Since both are one-dimensional NumPy arrays
pred_series = pd.Series(pred.flatten())
y_test_target_series = pd.Series(y_test)
y_train_target_series = pd.Series(y_train)

# %% [markdown]
# Create a subset of the Train DF for faster training

# %%
subset_percentage = 0.1
X_subset, _, y_subset, _ = train_test_split(X_train, y_train, test_size=1 - subset_percentage, stratify=y_train)

# %%
subset_percentage = 0.1
X_subset_labeled, _, y_subset_labeled, _ = train_test_split(X_train_labeled, y_train_target_series, test_size=1 - subset_percentage, stratify=y_train_target_series)

# %% [markdown]
# Row to explain

# %%
idx = 0

# %% [markdown]
# ---

# %% [markdown]
# ## Neural Network

# %%
weights = model.get_weights()

# Extract the first layer weights
input_layer_weights = weights[0]

feature_importance = np.mean(np.abs(input_layer_weights), axis=1)
df_feature_importance = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})
df_feature_importance = df_feature_importance.sort_values(by='Importance', ascending=False).reset_index(drop=True)

df_feature_importance
# Out:
#                   Feature  Importance
# 0    fwd_pkts_payload.min    0.234727
# 1     bwd_header_size_max    0.196375
# 2    fwd_pkts_payload.tot    0.177679
# 3   flow_pkts_payload.std    0.173825
# 4       bwd_subflow_bytes    0.172166
# 5    bwd_pkts_payload.avg    0.170628
# 6   flow_pkts_payload.tot    0.170573
# 7            bwd_pkts_tot    0.170382
# 8     fwd_header_size_min    0.167802
# 9    fwd_pkts_payload.std    0.166603
# 10      flow_pkts_per_sec    0.162661
# 11      fwd_data_pkts_tot    0.162284
# 12           fwd_pkts_tot    0.160292
# 13  flow_pkts_payload.avg    0.159691
# 14   bwd_pkts_payload.max    0.159182
# 15   fwd_pkts_payload.avg    0.157635
# 16  flow_pkts_payload.max    0.154865
# 17      fwd_subflow_bytes    0.154400
# 18       bwd_pkts_per_sec    0.150392
# 19       fwd_pkts_per_sec    0.148752
# 20       bwd_subflow_pkts    0.147913
# 21          down_up_ratio    0.146883
# 22   fwd_pkts_payload.max    0.146867
# 23       fwd_subflow_pkts    0.144189
# 24   bwd_pkts_payload.tot    0.140591
# 25    fwd_header_size_tot    0.137240
# 26    fwd_header_size_max    0.136423
# 27    bwd_header_size_tot    0.130630
# 28   bwd_pkts_payload.std    0.127119
# 29      bwd_data_pkts_tot    0.125650
# 30   bwd_pkts_payload.min    0.110186
# 31  flow_pkts_payload.min    0.100327
# 32    bwd_header_size_min    0.096803

# %% [markdown]
# ## Imodels

# %%
import imodels
from imodels import FIGSClassifier

#model_figs = FIGSClassifier(max_rules=7, max_trees=3)
#model_figs.fit(X_test_labeled, y_test_target_series, feature_names=feature_names)

dfp_importance = pd.DataFrame({'feat_names': feature_names})
dfp_importance['feature'] = dfp_importance.index
dfp_importance_gini = pd.DataFrame({'importance_gini': feature_importance})
dfp_importance_gini['feature'] = dfp_importance_gini.index
dfp_importance_gini['importance_gini_pct'] = dfp_importance_gini['importance_gini'].rank(pct=True)
dfp_importance = pd.merge(dfp_importance, dfp_importance_gini, on='feature', how='left')
dfp_importance = dfp_importance.sort_values(by=['importance_gini', 'feature'], ascending=[False, True]).reset_index(drop=True)
display(dfp_importance)
# Out:
#                feat_names  feature  importance_gini  importance_gini_pct
# 0    fwd_pkts_payload.min       14         0.234727             1.000000
# 1     bwd_header_size_max       13         0.196375             0.969697
# 2    fwd_pkts_payload.tot       16         0.177679             0.939394
# 3   flow_pkts_payload.std       28         0.173825             0.909091
# 4       bwd_subflow_bytes       32         0.172166             0.878788
# 5    bwd_pkts_payload.avg       22         0.170628             0.848485
# 6   flow_pkts_payload.tot       26         0.170573             0.818182
# 7            bwd_pkts_tot        1         0.170382             0.787879
# 8     fwd_header_size_min        9         0.167802             0.757576
# 9    fwd_pkts_payload.std       18         0.166603             0.727273
# 10      flow_pkts_per_sec        6         0.162661             0.696970
# 11      fwd_data_pkts_tot        2         0.162284             0.666667
# 12           fwd_pkts_tot        0         0.160292             0.636364
# 13  flow_pkts_payload.avg       27         0.159691             0.606061
# 14   bwd_pkts_payload.max       20         0.159182             0.575758
# 15   fwd_pkts_payload.avg       17         0.157635             0.545455
# 16  flow_pkts_payload.max       25         0.154865             0.515152
# 17      fwd_subflow_bytes       31         0.154400             0.484848
# 18       bwd_pkts_per_sec        5         0.150392             0.454545
# 19       fwd_pkts_per_sec        4         0.148752             0.424242
# 20       bwd_subflow_pkts       30         0.147913             0.393939
# 21          down_up_ratio        7         0.146883             0.363636
# 22   fwd_pkts_payload.max       15         0.146867             0.333333
# 23       fwd_subflow_pkts       29         0.144189             0.303030
# 24   bwd_pkts_payload.tot       21         0.140591             0.272727
# 25    fwd_header_size_tot        8         0.137240             0.242424
# 26    fwd_header_size_max       10         0.136423             0.212121
# 27    bwd_header_size_tot       11         0.130630             0.181818
# 28   bwd_pkts_payload.std       23         0.127119             0.151515
# 29      bwd_data_pkts_tot        3         0.125650             0.121212
# 30   bwd_pkts_payload.min       19         0.110186             0.090909
# 31  flow_pkts_payload.min       24         0.100327             0.060606
# 32    bwd_header_size_min       12         0.096803             0.030303

# %% [markdown]
# ## Shap

# %%
import shap

masker = shap.maskers.Independent(X_subset)

explainer = shap.Explainer(model, masker=masker)
#explainer = shap.KernelExplainer(model, data=X_subset)
#explainer = shap.TreeExplainer(model)

shap_values = explainer.shap_values(X_test_labeled)

shap.summary_plot(shap_values, X_test_labeled,feature_names=feature_names,class_names=class_names)
# Out:
# shap_values() is deprecated; use __call__().
# PermutationExplainer explainer: 15223it [09:37, 25.97it/s]

# %% [markdown]
# ## Shapash

# %%
from shapash import SmartExplainer

#pred_series_shapash = pred_series.iloc[:len(X_test_labeled)]
pred_series_shapash.index = X_test_subset_labeled.index

xpl = SmartExplainer(model=model)
xpl.compile(x=X_test_labeled,
            y_pred=pred_series,
            y_target=y_test_target_series)

xpl.plot.features_importance()
# Out:
# INFO: Shap explainer type - shap.explainers.PermutationExplainer()
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
# /home/ivoafonsobispo/.local/lib/python3.10/site-packages/shapash/utils/model.py:105: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# PermutationExplainer explainer:   0%|                                    | 13/15222 [00:00<?, ?it/s]
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 349us/step
# PermutationExplainer explainer:   0%|                          | 15/15222 [00:11<1:47:38,  2.35it/s]
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step
# PermutationExplainer explainer:   0%|                          | 16/15222 [00:11<2:36:08,  1.62it/s]
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 354us/step
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# PermutationExplainer explainer:   0%|                          | 17/15222 [00:12<3:01:51,  1.39it/s]
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 350us/step
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# PermutationExplainer explainer:   0%|                          | 18/15222 [00:13<3:02:29,  1.39it/s]
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# PermutationExplainer explainer:   0%|                          | 19/15222 [00:14<3:08:38,  1.34it/s]
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step
# PermutationExplainer explainer:   0%|                          | 20/15222 [00:15<3:22:16,  1.25it/s]
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 341us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step
# PermutationExplainer explainer:   0%|                          | 21/15222 [00:16<3:28:05,  1.22it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 353us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step
# PermutationExplainer explainer:   0%|                          | 22/15222 [00:16<3:14:13,  1.30it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 349us/step
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# PermutationExplainer explainer:   0%|                          | 23/15222 [00:17<3:05:55,  1.36it/s]
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# PermutationExplainer explainer:   0%|                          | 24/15222 [00:18<3:01:53,  1.39it/s]
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# PermutationExplainer explainer:   0%|                          | 25/15222 [00:19<3:17:14,  1.28it/s]
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# PermutationExplainer explainer:   0%|                          | 26/15222 [00:19<3:24:06,  1.24it/s]
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 353us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 351us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 351us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# PermutationExplainer explainer:   0%|                          | 27/15222 [00:20<3:18:01,  1.28it/s]
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 344us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step
# PermutationExplainer explainer:   0%|                          | 28/15222 [00:21<3:17:12,  1.28it/s]
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# PermutationExplainer explainer:   0%|                          | 29/15222 [00:22<3:13:51,  1.31it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 353us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 345us/step
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step
# PermutationExplainer explainer:   0%|                          | 30/15222 [00:22<3:05:30,  1.36it/s]
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 354us/step
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# PermutationExplainer explainer:   0%|                          | 31/15222 [00:23<3:09:53,  1.33it/s]
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# PermutationExplainer explainer:   0%|                          | 32/15222 [00:24<3:05:10,  1.37it/s]
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 345us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# PermutationExplainer explainer:   0%|                          | 33/15222 [00:24<3:01:39,  1.39it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 353us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 347us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# PermutationExplainer explainer:   0%|                          | 34/15222 [00:25<2:58:11,  1.42it/s]
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step
# PermutationExplainer explainer:   0%|                          | 35/15222 [00:26<3:08:02,  1.35it/s]
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 342us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step
# PermutationExplainer explainer:   0%|                          | 36/15222 [00:27<3:18:12,  1.28it/s]
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 351us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 349us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# PermutationExplainer explainer:   0%|                          | 37/15222 [00:28<3:21:22,  1.26it/s]
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# PermutationExplainer explainer:   0%|                          | 38/15222 [00:28<3:21:25,  1.26it/s]
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step
# PermutationExplainer explainer:   0%|                          | 39/15222 [00:29<3:22:45,  1.25it/s]
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# PermutationExplainer explainer:   0%|                          | 40/15222 [00:30<3:34:22,  1.18it/s]
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# PermutationExplainer explainer:   0%|                          | 41/15222 [00:31<3:43:40,  1.13it/s]
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# PermutationExplainer explainer:   0%|                          | 42/15222 [00:32<3:48:51,  1.11it/s]
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# PermutationExplainer explainer:   0%|                          | 43/15222 [00:33<3:44:56,  1.12it/s]
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# PermutationExplainer explainer:   0%|                          | 44/15222 [00:34<3:37:28,  1.16it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# PermutationExplainer explainer:   0%|                          | 45/15222 [00:35<3:27:17,  1.22it/s]
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# PermutationExplainer explainer:   0%|                          | 46/15222 [00:35<3:28:56,  1.21it/s]
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step
# PermutationExplainer explainer:   0%|                          | 47/15222 [00:36<3:20:59,  1.26it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# PermutationExplainer explainer:   0%|                          | 48/15222 [00:37<3:16:26,  1.29it/s]
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# PermutationExplainer explainer:   0%|                          | 49/15222 [00:38<3:24:33,  1.24it/s]
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# PermutationExplainer explainer:   0%|                          | 50/15222 [00:39<3:35:02,  1.18it/s]
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step
# PermutationExplainer explainer:   0%|                          | 51/15222 [00:39<3:26:30,  1.22it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# PermutationExplainer explainer:   0%|                          | 52/15222 [00:40<3:20:20,  1.26it/s]
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# PermutationExplainer explainer:   0%|                          | 53/15222 [00:41<3:32:44,  1.19it/s]
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# PermutationExplainer explainer:   0%|                          | 54/15222 [00:42<3:40:23,  1.15it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# PermutationExplainer explainer:   0%|                          | 55/15222 [00:43<3:28:39,  1.21it/s]
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# PermutationExplainer explainer:   0%|                          | 56/15222 [00:44<3:25:50,  1.23it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step
# PermutationExplainer explainer:   0%|                          | 57/15222 [00:44<3:20:56,  1.26it/s]
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# PermutationExplainer explainer:   0%|                          | 58/15222 [00:45<3:32:57,  1.19it/s]
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step
# PermutationExplainer explainer:   0%|                          | 59/15222 [00:46<3:41:48,  1.14it/s]
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# PermutationExplainer explainer:   0%|                          | 60/15222 [00:47<3:39:36,  1.15it/s]
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# PermutationExplainer explainer:   0%|                          | 61/15222 [00:48<3:34:34,  1.18it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# PermutationExplainer explainer:   0%|                          | 62/15222 [00:49<3:25:04,  1.23it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# PermutationExplainer explainer:   0%|                          | 63/15222 [00:49<3:17:46,  1.28it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# PermutationExplainer explainer:   0%|                          | 64/15222 [00:50<3:13:44,  1.30it/s]
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# PermutationExplainer explainer:   0%|                          | 65/15222 [00:51<3:24:24,  1.24it/s]
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step
# PermutationExplainer explainer:   0%|                          | 66/15222 [00:52<3:39:00,  1.15it/s]
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# PermutationExplainer explainer:   0%|                          | 67/15222 [00:53<3:39:13,  1.15it/s]
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# PermutationExplainer explainer:   0%|                          | 68/15222 [00:54<3:34:22,  1.18it/s]
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# PermutationExplainer explainer:   0%|                          | 69/15222 [00:54<3:27:09,  1.22it/s]
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# PermutationExplainer explainer:   0%|                          | 70/15222 [00:55<3:38:07,  1.16it/s]
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# PermutationExplainer explainer:   0%|                          | 71/15222 [00:56<3:31:04,  1.20it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step
# PermutationExplainer explainer:   0%|                          | 72/15222 [00:57<3:22:54,  1.24it/s]
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step
# PermutationExplainer explainer:   0%|                          | 73/15222 [00:58<3:18:38,  1.27it/s]
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step
# PermutationExplainer explainer:   0%|▏                         | 74/15222 [00:58<3:15:35,  1.29it/s]
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# PermutationExplainer explainer:   0%|▏                         | 75/15222 [00:59<3:28:20,  1.21it/s]
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# PermutationExplainer explainer:   0%|▏                         | 76/15222 [01:00<3:28:06,  1.21it/s]
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# PermutationExplainer explainer:   1%|▏                         | 77/15222 [01:01<3:22:04,  1.25it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step
# PermutationExplainer explainer:   1%|▏                         | 78/15222 [01:02<3:16:32,  1.28it/s]
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# PermutationExplainer explainer:   1%|▏                         | 79/15222 [01:02<3:27:38,  1.22it/s]
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# PermutationExplainer explainer:   1%|▏                         | 80/15222 [01:03<3:24:29,  1.23it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# PermutationExplainer explainer:   1%|▏                         | 81/15222 [01:04<3:17:09,  1.28it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# PermutationExplainer explainer:   1%|▏                         | 82/15222 [01:05<3:12:12,  1.31it/s]
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# PermutationExplainer explainer:   1%|▏                         | 83/15222 [01:05<3:13:17,  1.31it/s]
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# PermutationExplainer explainer:   1%|▏                         | 84/15222 [01:06<3:14:24,  1.30it/s]
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# PermutationExplainer explainer:   1%|▏                         | 85/15222 [01:07<3:26:15,  1.22it/s]
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# PermutationExplainer explainer:   1%|▏                         | 86/15222 [01:08<3:18:29,  1.27it/s]
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# PermutationExplainer explainer:   1%|▏                         | 87/15222 [01:09<3:22:21,  1.25it/s]
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# PermutationExplainer explainer:   1%|▏                         | 88/15222 [01:10<3:34:32,  1.18it/s]
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# PermutationExplainer explainer:   1%|▏                         | 89/15222 [01:11<3:33:01,  1.18it/s]
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# PermutationExplainer explainer:   1%|▏                         | 90/15222 [01:11<3:40:23,  1.14it/s]
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# PermutationExplainer explainer:   1%|▏                         | 91/15222 [01:12<3:30:37,  1.20it/s]
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# PermutationExplainer explainer:   1%|▏                         | 92/15222 [01:13<3:32:29,  1.19it/s]
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# PermutationExplainer explainer:   1%|▏                         | 93/15222 [01:14<3:29:24,  1.20it/s]
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# PermutationExplainer explainer:   1%|▏                         | 94/15222 [01:15<3:38:05,  1.16it/s]
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# PermutationExplainer explainer:   1%|▏                         | 95/15222 [01:16<3:30:25,  1.20it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# PermutationExplainer explainer:   1%|▏                         | 96/15222 [01:16<3:20:24,  1.26it/s]
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# PermutationExplainer explainer:   1%|▏                         | 97/15222 [01:17<3:20:11,  1.26it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# PermutationExplainer explainer:   1%|▏                         | 98/15222 [01:18<3:13:45,  1.30it/s]
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# PermutationExplainer explainer:   1%|▏                         | 99/15222 [01:19<3:25:36,  1.23it/s]
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# PermutationExplainer explainer:   1%|▏                        | 100/15222 [01:20<3:34:16,  1.18it/s]
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 433us/step
# PermutationExplainer explainer:   1%|▏                        | 101/15222 [01:21<3:54:04,  1.08it/s]
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# PermutationExplainer explainer:   1%|▏                        | 102/15222 [01:22<3:46:13,  1.11it/s]
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# PermutationExplainer explainer:   1%|▏                        | 103/15222 [01:23<3:50:54,  1.09it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step
# PermutationExplainer explainer:   1%|▏                        | 104/15222 [01:23<3:38:07,  1.16it/s]
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step
# PermutationExplainer explainer:   1%|▏                        | 105/15222 [01:24<3:32:04,  1.19it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# PermutationExplainer explainer:   1%|▏                        | 106/15222 [01:25<3:24:39,  1.23it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step
# PermutationExplainer explainer:   1%|▏                        | 107/15222 [01:26<3:19:27,  1.26it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step
# PermutationExplainer explainer:   1%|▏                        | 108/15222 [01:26<3:14:09,  1.30it/s]
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# PermutationExplainer explainer:   1%|▏                        | 109/15222 [01:27<3:26:23,  1.22it/s]
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step
# PermutationExplainer explainer:   1%|▏                        | 110/15222 [01:28<3:22:52,  1.24it/s]
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step
# ...
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# PermutationExplainer explainer:   5%|█▏                       | 691/15222 [08:56<3:11:15,  1.27it/s]
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# PermutationExplainer explainer:   5%|█▏                       | 692/15222 [08:57<3:20:20,  1.21it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# PermutationExplainer explainer:   5%|█▏                       | 693/15222 [08:57<3:09:20,  1.28it/s]
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 329us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 350us/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# PermutationExplainer explainer:   5%|█▏                       | 694/15222 [08:58<3:08:02,  1.29it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# PermutationExplainer explainer:   5%|█▏                       | 695/15222 [08:59<3:01:01,  1.34it/s]
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# PermutationExplainer explainer:   5%|█▏                       | 696/15222 [08:59<3:02:39,  1.33it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 350us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# PermutationExplainer explainer:   5%|█▏                       | 697/15222 [09:00<2:56:32,  1.37it/s]
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 342us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 354us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step
# PermutationExplainer explainer:   5%|█▏                       | 698/15222 [09:01<3:05:54,  1.30it/s]
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 342us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step
# PermutationExplainer explainer:   5%|█▏                       | 699/15222 [09:02<3:15:06,  1.24it/s]
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step
# PermutationExplainer explainer:   5%|█▏                       | 700/15222 [09:03<3:21:40,  1.20it/s]
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step
# PermutationExplainer explainer:   5%|█▏                       | 701/15222 [09:04<3:25:44,  1.18it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 351us/step
# PermutationExplainer explainer:   5%|█▏                       | 702/15222 [09:04<3:12:47,  1.26it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# PermutationExplainer explainer:   5%|█▏                       | 703/15222 [09:05<3:04:01,  1.31it/s]
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# PermutationExplainer explainer:   5%|█▏                       | 704/15222 [09:06<3:00:49,  1.34it/s]
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
# PermutationExplainer explainer:   5%|█▏                       | 705/15222 [09:06<3:00:55,  1.34it/s]
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step
#   1/144 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# PermutationExplainer explainer:   5%|█▏                       | 705/15222 [09:07<3:11:19,  1.26it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 7
#       4 #pred_series_shapash.index = X_test_subset_labeled.index
#       6 xpl = SmartExplainer(model=model)
# ----> 7 xpl.compile(x=X_test_labeled,
#       8             y_pred=pred_series,
#       9             y_target=y_test_target_series)
#      11 xpl.plot.features_importance()
#
# File ~/.local/lib/python3.10/site-packages/shapash/explainer/smart_explainer.py:297, in SmartExplainer.compile(self, x, contributions, y_pred, y_target, additional_data, additional_features_dict)
#     294 self.y_target = check_y(self.x_init, y_target, y_name="y_target")
#     295 self.prediction_error = predict_error(self.y_target, self.y_pred, self._case)
# --> 297 self._get_contributions_from_backend_or_user(x, contributions)
#     298 self.check_contributions()
#     300 self.columns_dict = {i: col for i, col in enumerate(self.x_init.columns)}
#
# File ~/.local/lib/python3.10/site-packages/shapash/explainer/smart_explainer.py:319, in SmartExplainer._get_contributions_from_backend_or_user(self, x, contributions)
#     316 def _get_contributions_from_backend_or_user(self, x, contributions):
#     317     # Computing contributions using backend
#     318     if contributions is None:
# --> 319         self.explain_data = self.backend.run_explainer(x=x)
#     320         self.contributions = self.backend.get_local_contributions(x=x, explain_data=self.explain_data)
#     321     else:
#
# File ~/.local/lib/python3.10/site-packages/shapash/backend/shap_backend.py:59, in ShapBackend.run_explainer(self, x)
#      45 """
#      46 Computes and returns local contributions using Shap explainer
#      47
#    (...)
#      56     local contributions
#      57 """
#      58 print("INFO: Shap explainer type -", self.explainer)
# ---> 59 contributions = self.explainer(x, **self.explainer_compute_args)
#      60 explain_data = dict(contributions=contributions.values)
#      61 return explain_data
#
# File ~/.local/lib/python3.10/site-packages/shap/explainers/_permutation.py:79, in PermutationExplainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args)
#      75 def __call__(self, *args, max_evals=500, main_effects=False, error_bounds=False, batch_size="auto",
#      76              outputs=None, silent=False):
#      77     """ Explain the output of the model on the given arguments.
#      78     """
# ---> 79     return super().__call__(
#      80         *args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds, batch_size=batch_size,
#      81         outputs=outputs, silent=silent
#      82     )
#
# File ~/.local/lib/python3.10/site-packages/shap/explainers/_explainer.py:267, in Explainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     265     feature_names = [[] for _ in range(len(args))]
#     266 for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__+" explainer", silent):
# --> 267     row_result = self.explain_row(
#     268         *row_args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds,
#     269         batch_size=batch_size, outputs=outputs, silent=silent, **kwargs
#     270     )
#     271     values.append(row_result.get("values", None))
#     272     output_indices.append(row_result.get("output_indices", None))
#
# File ~/.local/lib/python3.10/site-packages/shap/explainers/_permutation.py:137, in PermutationExplainer.explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *row_args)
#     134     i += 1
#     136 # evaluate the masked model
# --> 137 outputs = fm(masks, zero_index=0, batch_size=batch_size)
#     139 if row_values is None:
#     140     row_values = np.zeros((len(fm),) + outputs.shape[1:])
#
# File ~/.local/lib/python3.10/site-packages/shap/utils/_masked_model.py:59, in MaskedModel.__call__(self, masks, zero_index, batch_size)
#      57 if len(masks.shape) == 1:
#      58     if getattr(self.masker, "supports_delta_masking", False):
# ---> 59         return self._delta_masking_call(masks, zero_index=zero_index, batch_size=batch_size)
#      61     # we need to convert from delta masking to a full masking call because we were given a delta masking
#      62     # input but the masker does not support delta masking
#      63     else:
#      64         full_masks = np.zeros((int(np.sum(masks >= 0)), self._masker_cols), dtype=bool)
#
# File ~/.local/lib/python3.10/site-packages/shap/utils/_masked_model.py:205, in MaskedModel._delta_masking_call(self, masks, zero_index, batch_size)
#     202     batch_positions[i+1] = batch_positions[i] + num_varying_rows[i]
#     204 # joined_masked_inputs = self._stack_inputs(all_masked_inputs)
# --> 205 outputs = self.model(*subset_masked_inputs)
#     206 _assert_output_input_match(subset_masked_inputs, outputs)
#     208 if self.linearize_link and self.link != links.identity and self._linearizing_weights is None:
#
# File ~/.local/lib/python3.10/site-packages/shap/models/_model.py:28, in Model.__call__(self, *args)
#      27 def __call__(self, *args):
# ---> 28     out = self.inner_model(*args)
#      29     is_tensor = safe_isinstance(out, "torch.Tensor")
#      30     out = out.cpu().detach().numpy() if is_tensor else np.array(out)
#
# File ~/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:513, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     511 callbacks.on_predict_batch_begin(step)
#     512 data = get_data(iterator)
# --> 513 batch_outputs = self.predict_function(data)
#     514 outputs = append_to_outputs(batch_outputs, outputs)
#     515 callbacks.on_predict_batch_end(step, {"outputs": batch_outputs})
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:877, in Function._call(self, *args, **kwds)
#     874 self._lock.release()
#     875 # In this case we have not created variables on the first call. So we can
#     876 # run the first trace but we should fail if variables are created.
# --> 877 results = tracing_compilation.call_function(
#     878     args, kwds, self._variable_creation_config
#     879 )
#     880 if self._created_variables:
#     881   raise ValueError("Creating variables on a non-first call to a function"
#     882                    " decorated with tf.function.")
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# KeyboardInterrupt:

# %%
app = xpl.run_app(title_story='Farm-Flow', port=8020)
#app.kill()

# %% [markdown]
# ## InterpretML

# %%
print(model.input_shape)

# %%
from interpret.blackbox import MorrisSensitivity
from sklearn.pipeline import Pipeline
from interpret import show
from keras.models import Model

functional_model = Model(inputs=model.input, outputs=model.output)

def predict_fn(X_test_labeled):
    return model.predict(X_test_labeled)

msa = MorrisSensitivity(predict_fn, X_test_labeled, feature_names=feature_names)

show(msa.explain_global())

# %% [markdown]
# ## LOFO

# %%
from lofo import LOFOImportance, Dataset, plot_importance
from sklearn.model_selection import KFold

target_name = "is_attack"

column_names = feature_names + [target_name]

combined_data = np.column_stack((X_test_labeled, y_test_target_series))
combined_df = pd.DataFrame(combined_data, columns=column_names)

# define the validation scheme
cv = KFold(n_splits=4, shuffle=False, random_state=None) # Don't shuffle to keep the time split split validation

# define the binary target and the features
dataset = Dataset(df=combined_df, target="is_attack", features=[col for col in combined_df.columns if col != "is_attack"])

# define the validation scheme and scorer. The default model is LightGBM
lofo_imp = LOFOImportance(dataset, cv=cv, scoring="roc_auc")

# get the mean and standard deviation of the importances in pandas format
importance = lofo_imp.get_importance()

importance

# %% [markdown]
# ------
# ## Notes
#
# **SHAP Values vs Permutation Importance vs Morris Sensitivity vs LOFO (Leave One Feature Out)**
#
# 1. **SHAP Values:**
# - **Concept:** SHAP values are based on cooperative game theory and aim to fairly distribute the contribution of each feature to the model's prediction.
# - **How it works:** It calculates the average contribution of each feature across all possible feature combinations and assigns a value to each feature, indicating its impact on the prediction.
# - **Interpretation:** A positive SHAP value for a feature contributes to increasing the model's output, while a negative value indicates a contribution to decreasing the output.
#
# 2. **Permutation Importance:**
# - **Concept:** Permutation Importance assesses the importance of each feature by permuting (randomly shuffling) its values and observing the change in the model's performance.
# - **How it works:** It measures the decrease in model performance (e.g., accuracy) when the values of a specific feature are randomly permuted, and the larger the decrease, the more important the feature is considered.
# - **Interpretation:** A higher decrease in performance suggests that the feature is crucial for the model's predictions.
#
# 3. **Morris Sensitivity:**
# - **Concept:** Morris Sensitivity is a global sensitivity analysis method that assesses the impact of small variations in individual features on the model's output.
# - **How it works:** It involves perturbing one feature at a time while keeping other features constant, observing how the output changes, and quantifying the sensitivity of the model to each feature.
# - **Interpretation:** A higher Morris Sensitivity value indicates a greater impact of the feature on the model output.
#
# 4. **LOFO (Leave One Feature Out):**
# - **Concept:** LOFO evaluates the impact of leaving out each feature one at a time on the model's performance.
# - **How it works:** It systematically removes each feature, re-trains the model, and measures the change in performance metrics (e.g., accuracy, AUC) to understand the importance of each feature.
# - **Interpretation:** A larger decrease in performance when a specific feature is left out suggests that the feature is more critical for the model's predictions.
#
# **Assumptions:**
# - **SHAP Values:** Assumes that features interact cooperatively.
# - **Permutation Importance:** Assumes that the change in model performance is solely due to the importance of the feature.
# - **Morris Sensitivity:** Assumes small variations in individual features.
# - **LOFO:** Assumes that leaving out a feature impacts the model's performance.
#
# ### Q: Why are the results from the XGBoost Feature Importance different from the results of the DNN?
# XGBoost relies on decision trees, where each feature's importance is determined by its contribution to the reduction in impurity (Gini) in the decision tree nodes. Results in a clear and interpretable feature importance. On the other hand, DNNs are non-linear models, making them harder to interpret.
#
# **In cybersecurity:**
#
# The text discusses the number of packets with payload as a common feature, and asserts that the results vary based on the type of Feature Importance algorithm used.
#
# - **Permutation Importance:** identifies the time between each package sent as having the most influence.
# - **Shap:** identifies backward communication starting with subflow or packet size as having the most influence.
# - **Morris Sensitivity:** the minimum payload size has been identified as having the most influence, which is reasonable given that it is an IoT dataset and consistency in the minimum payload size is crucial.
# - **LOFO:** despite being mentioned after several other features, another proposition suggests that the payload size, including the packet header size, has more influence.
#
# Understanding each feature with XGBoost is possible, but it becomes challenging with NN due to the varying results obtained from different techniques. Nevertheless, the packet consistently yields the same result across all techniques.
#
# This highlights the importance of considering the interpretability of models, especially when dealing with complex neural networks, and understanding that different interpretability techniques may yield divergent results. The consistency in the interpretation of the "packet" feature across various techniques adds confidence to its significance in the context of the cybersecurity dataset.
