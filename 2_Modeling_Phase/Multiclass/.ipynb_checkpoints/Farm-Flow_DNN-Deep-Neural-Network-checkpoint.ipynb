# %% [markdown]
# # DNN

# %% [markdown]
# ## Import and Reading Data

# %%
#pip install tensorflow

# %%
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf
# Out:
# 2024-03-19 12:10:28.031012: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-19 12:10:28.031416: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-19 12:10:28.034060: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-19 12:10:28.063877: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-19 12:10:28.603813: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df_train = pd.read_csv("../../0_Datasets/Farm-Flow/train.csv")

# %%
display(df_train)
# Out:
#        fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  \
# 0         -0.236304     -0.662387          -0.577140          -0.443123
# 1         -0.672105     -0.457813          -0.577140          -0.443123
# 2         -0.454205     -0.662387          -0.577140          -0.443123
# 3          2.378496      2.406229           2.285759           2.444445
# 4         -0.672105     -0.457813          -0.577140          -0.443123
# ...             ...           ...                ...                ...
# 47341     -0.454205     -0.457813          -0.577140          -0.443123
# 47342     -0.454205     -0.662387          -0.577140          -0.443123
# 47343      2.160596      1.997080           2.285759           2.444445
# 47344      1.288996      1.383357           1.713179           0.711904
# 47345     -0.672105     -0.457813          -0.577140          -0.443123
#
#        fwd_pkts_per_sec  bwd_pkts_per_sec  flow_pkts_per_sec  down_up_ratio  \
# 0             -0.277741         -0.268577          -0.273647      -1.394192
# 1              0.490111          0.504662           0.498222       0.728588
# 2             -0.277918         -0.268577          -0.273736      -1.394192
# 3             -0.276874         -0.267504          -0.272675       0.728588
# 4             -0.277823         -0.268460          -0.273629       0.728588
# ...                 ...               ...                ...            ...
# 47341         -0.276776         -0.267991          -0.272869      -0.332802
# 47342         -0.277509         -0.268577          -0.273530      -1.394192
# 47343         -0.276943         -0.267646          -0.272781       0.576960
# 47344         -0.265775         -0.256330          -0.261520       0.728588
# 47345         -0.277865         -0.268501          -0.273671       0.728588
#
#        fwd_header_size_tot  fwd_header_size_min  ...  flow_pkts_payload.max  \
# 0                -0.643844            -1.423582  ...              -0.562720
# 1                -0.643844             0.278456  ...              -0.562720
# 2                -0.724235            -1.423582  ...              -0.562720
# 3                 2.129645            -0.147053  ...              -0.240860
# 4                -0.684039            -0.147053  ...              -0.562720
# ...                    ...                  ...  ...                    ...
# 47341            -0.483062            -0.147053  ...              -0.562720
# 47342            -0.724235            -1.423582  ...              -0.562720
# 47343             1.928668            -0.147053  ...              -0.240860
# 47344             2.330623             1.129475  ...              -0.250326
# 47345            -0.684039            -0.147053  ...              -0.562720
#
#        flow_pkts_payload.tot  flow_pkts_payload.avg  flow_pkts_payload.std  \
# 0                  -0.744570              -0.562649              -0.557806
# 1                  -0.744570              -0.562649              -0.557806
# 2                  -0.744570              -0.562649              -0.557806
# 3                   1.678331              -0.105550              -0.268638
# 4                  -0.744570              -0.562649              -0.557806
# ...                      ...                    ...                    ...
# 47341              -0.744570              -0.562649              -0.557806
# 47342              -0.744570              -0.562649              -0.557806
# 47343               1.678331              -0.054762              -0.267306
# 47344               0.400251              -0.238680              -0.346375
# 47345              -0.744570              -0.562649              -0.557806
#
#        fwd_subflow_pkts  bwd_subflow_pkts  fwd_subflow_bytes  \
# 0             -0.556874         -0.638986          -0.741186
# 1             -0.556874         -0.419418          -0.741186
# 2             -0.556874         -0.638986          -0.741186
# 3              2.620142          2.654541           1.265201
# 4             -0.670339         -0.529202          -0.741186
# ...                 ...               ...                ...
# 47341         -0.329944         -0.419418          -0.741186
# 47342         -0.556874         -0.638986          -0.741186
# 47343          0.275202          0.312477          -0.072391
# 47344          1.485493          1.556699           0.470671
# 47345         -0.670339         -0.529202          -0.741186
#
#        bwd_subflow_bytes        traffic  is_attack
# 0              -0.418623      UDP_Flood          1
# 1              -0.418623  Port_Scanning          1
# 2              -0.418623      UDP_Flood          1
# 3               2.728235         Normal          0
# 4              -0.418623     MQTT_Flood          1
# ...                  ...            ...        ...
# 47341          -0.418623      TCP_Flood          1
# 47342          -0.418623      UDP_Flood          1
# 47343           0.630330         Normal          0
# 47344           0.378581         Normal          0
# 47345          -0.418623     MQTT_Flood          1
#
# [47346 rows x 35 columns]

# %%
df_test = pd.read_csv("../../0_Datasets/Farm-Flow/test.csv")

# %%
display(df_test)
# Out:
#        fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  \
# 0         -0.672105     -0.457813          -0.577140          -0.443123
# 1         -0.672105     -0.457813          -0.577140          -0.443123
# 2         -0.454205     -0.457813          -0.577140          -0.443123
# 3          2.378496      2.406229           2.285759           2.444445
# 4         -0.454205     -0.253238          -0.004560          -0.443123
# ...             ...           ...                ...                ...
# 15778      1.942696      2.201655           2.285759           2.444445
# 15779      2.160596      2.201655           2.285759           2.444445
# 15780     -0.236304     -0.662387          -0.577140          -0.443123
# 15781     -0.454205     -0.662387          -0.577140          -0.443123
# 15782     -0.236304     -0.662387          -0.577140          -0.443123
#
#        fwd_pkts_per_sec  bwd_pkts_per_sec  flow_pkts_per_sec  down_up_ratio  \
# 0             -0.276940         -0.267571          -0.272742       0.728588
# 1             -0.277181         -0.267813          -0.272983       0.728588
# 2             -0.276909         -0.268058          -0.272969      -0.332802
# 3             -0.276907         -0.267537          -0.272708       0.728588
# 4             -0.276892         -0.267522          -0.272693       0.728588
# ...                 ...               ...                ...            ...
# 15778         -0.277003         -0.267561          -0.272768       0.891878
# 15779         -0.276991         -0.267622          -0.272793       0.728588
# 15780         -0.277906         -0.268577          -0.273730      -1.394192
# 15781         -0.277687         -0.268577          -0.273620      -1.394192
# 15782         -0.277882         -0.268577          -0.273718      -1.394192
#
#        fwd_header_size_tot  fwd_header_size_min  ...  flow_pkts_payload.max  \
# 0                -0.684039            -0.147053  ...              -0.562720
# 1                -0.684039            -0.147053  ...              -0.562720
# 2                -0.483062            -0.147053  ...              -0.562720
# 3                 2.129645            -0.147053  ...              -0.240860
# 4                -0.241889             1.129475  ...              -0.477522
# ...                    ...                  ...  ...                    ...
# 15778             1.727690            -0.147053  ...              -0.240860
# 15779             1.928668            -0.147053  ...              -0.240860
# 15780            -0.643844            -1.423582  ...              -0.562720
# 15781            -0.724235            -1.423582  ...              -0.562720
# 15782            -0.643844            -1.423582  ...              -0.562720
#
#        flow_pkts_payload.tot  flow_pkts_payload.avg  flow_pkts_payload.std  \
# 0                  -0.744570              -0.562649              -0.557806
# 1                  -0.744570              -0.562649              -0.557806
# 2                  -0.744570              -0.562649              -0.557806
# 3                   1.678331              -0.105550              -0.268638
# 4                  -0.635539              -0.408378              -0.455263
# ...                      ...                    ...                    ...
# 15778               1.678331              -0.054762              -0.267306
# 15779               1.678331              -0.072901              -0.267431
# 15780              -0.744570              -0.562649              -0.557806
# 15781              -0.744570              -0.562649              -0.557806
# 15782              -0.744570              -0.562649              -0.557806
#
#        fwd_subflow_pkts  bwd_subflow_pkts  fwd_subflow_bytes  \
# 0             -0.556874         -0.419418          -0.741186
# 1             -0.556874         -0.419418          -0.741186
# 2             -0.329944         -0.419418          -0.741186
# 3              2.620142          2.654541           1.265201
# 4             -0.329944         -0.199849          -0.596727
# ...                 ...               ...                ...
# 15778          0.691239          0.897993           0.262007
# 15779          2.393212          2.434972           1.265201
# 15780         -0.556874         -0.638986          -0.741186
# 15781         -0.556874         -0.638986          -0.741186
# 15782         -0.556874         -0.638986          -0.741186
#
#        bwd_subflow_bytes       traffic  is_attack
# 0              -0.418623    MQTT_Flood          1
# 1              -0.418623    MQTT_Flood          1
# 2              -0.418623     TCP_Flood          1
# 3               2.728235        Normal          0
# 4              -0.418623    HTTP_Flood          1
# ...                  ...           ...        ...
# 15778           1.154806  Arp_Spoofing          1
# 15779           2.728235        Normal          0
# 15780          -0.418623     UDP_Flood          1
# 15781          -0.418623     UDP_Flood          1
# 15782          -0.418623     UDP_Flood          1
#
# [15783 rows x 35 columns]

# %% [markdown]
# -----
# ## Create Model and Train Model

# %%
df_train = df_train.drop('is_attack', axis=1)
df_test = df_test.drop('is_attack', axis=1)

# %%
X_columns = df_train.columns.drop('traffic')

le = LabelEncoder()
le.fit(df_train["traffic"].values)

X = df_train[X_columns].values
y = df_train["traffic"].values
y = le.transform(y)

# %%
X_columns_val = df_test.columns.drop('traffic')

le = LabelEncoder()
le.fit(df_test["traffic"].values)

X_val = df_test[X_columns].values
y_val = df_test["traffic"].values
y_val = le.transform(y_val)

# %%
# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

# %%
X_test.shape,y_test.shape
# Out:
# ((11837, 33), (11837,))

# %%
X_train.shape,y_train.shape
# Out:
# ((35509, 33), (35509,))

# %%
X_val.shape, y_val.shape
# Out:
# ((15783, 33), (15783,))

# %%
import numpy as np

unique_labels = np.unique(y_train)
print("Unique labels in y_train:", unique_labels)
# Out:
# Unique labels in y_train: [0 1 2 3 4 5 6 7 8]

# %%
# Define the model
model = Sequential()
model.add(Dense(30, input_dim=X_train.shape[1], activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(60, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(30, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(15, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(9, activation='softmax')) 

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

monitor = tf.keras.callbacks.ReduceLROnPlateau(monitor="loss",factor=0.5,mode="min",patience=10,verbose=1,min_lr=1e-7)
checkpoint = ModelCheckpoint('Saved-Models/Farm-Flow_DNN-Deep-Neural-Network_Model.keras', monitor='val_loss', save_best_only=True)

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=300, batch_size=512, callbacks=[monitor, checkpoint])
# Out:
# Epoch 1/300
# /home/ivoafonsobispo/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:85: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-03-19 12:10:29.315067: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-19 12:10:29.315325: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1923 - loss: 2.5524 - val_accuracy: 0.4656 - val_loss: 1.8870 - learning_rate: 0.0100
# Epoch 2/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3026 - loss: 2.0757 - val_accuracy: 0.6503 - val_loss: 1.7088 - learning_rate: 0.0100
# Epoch 3/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3956 - loss: 1.8431 - val_accuracy: 0.6644 - val_loss: 1.5245 - learning_rate: 0.0100
# Epoch 4/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4582 - loss: 1.6879 - val_accuracy: 0.6889 - val_loss: 1.3673 - learning_rate: 0.0100
# Epoch 5/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5073 - loss: 1.5801 - val_accuracy: 0.7042 - val_loss: 1.2486 - learning_rate: 0.0100
# Epoch 6/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5317 - loss: 1.5049 - val_accuracy: 0.7087 - val_loss: 1.1596 - learning_rate: 0.0100
# Epoch 7/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5607 - loss: 1.4282 - val_accuracy: 0.7159 - val_loss: 1.0821 - learning_rate: 0.0100
# Epoch 8/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5782 - loss: 1.3747 - val_accuracy: 0.7286 - val_loss: 1.0154 - learning_rate: 0.0100
# Epoch 9/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5859 - loss: 1.3398 - val_accuracy: 0.7472 - val_loss: 0.9672 - learning_rate: 0.0100
# Epoch 10/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5974 - loss: 1.3003 - val_accuracy: 0.7488 - val_loss: 0.9209 - learning_rate: 0.0100
# Epoch 11/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6164 - loss: 1.2527 - val_accuracy: 0.7499 - val_loss: 0.8838 - learning_rate: 0.0100
# Epoch 12/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6250 - loss: 1.2222 - val_accuracy: 0.7555 - val_loss: 0.8470 - learning_rate: 0.0100
# Epoch 13/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6400 - loss: 1.1865 - val_accuracy: 0.7573 - val_loss: 0.8168 - learning_rate: 0.0100
# Epoch 14/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6359 - loss: 1.1862 - val_accuracy: 0.7580 - val_loss: 0.7962 - learning_rate: 0.0100
# Epoch 15/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6451 - loss: 1.1544 - val_accuracy: 0.7589 - val_loss: 0.7726 - learning_rate: 0.0100
# Epoch 16/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6513 - loss: 1.1309 - val_accuracy: 0.7590 - val_loss: 0.7529 - learning_rate: 0.0100
# Epoch 17/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6579 - loss: 1.1067 - val_accuracy: 0.7617 - val_loss: 0.7370 - learning_rate: 0.0100
# Epoch 18/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6636 - loss: 1.0888 - val_accuracy: 0.7616 - val_loss: 0.7210 - learning_rate: 0.0100
# Epoch 19/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6694 - loss: 1.0684 - val_accuracy: 0.7650 - val_loss: 0.7077 - learning_rate: 0.0100
# Epoch 20/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6740 - loss: 1.0558 - val_accuracy: 0.7665 - val_loss: 0.6961 - learning_rate: 0.0100
# Epoch 21/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6845 - loss: 1.0235 - val_accuracy: 0.7657 - val_loss: 0.6861 - learning_rate: 0.0100
# Epoch 22/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6833 - loss: 1.0115 - val_accuracy: 0.7661 - val_loss: 0.6758 - learning_rate: 0.0100
# Epoch 23/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6833 - loss: 1.0209 - val_accuracy: 0.7664 - val_loss: 0.6667 - learning_rate: 0.0100
# Epoch 24/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6900 - loss: 0.9923 - val_accuracy: 0.7659 - val_loss: 0.6559 - learning_rate: 0.0100
# Epoch 25/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6925 - loss: 0.9905 - val_accuracy: 0.7661 - val_loss: 0.6480 - learning_rate: 0.0100
# Epoch 26/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6973 - loss: 0.9661 - val_accuracy: 0.7667 - val_loss: 0.6392 - learning_rate: 0.0100
# Epoch 27/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7022 - loss: 0.9517 - val_accuracy: 0.7671 - val_loss: 0.6321 - learning_rate: 0.0100
# Epoch 28/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7014 - loss: 0.9423 - val_accuracy: 0.7674 - val_loss: 0.6247 - learning_rate: 0.0100
# Epoch 29/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7033 - loss: 0.9361 - val_accuracy: 0.7678 - val_loss: 0.6188 - learning_rate: 0.0100
# Epoch 30/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7045 - loss: 0.9373 - val_accuracy: 0.7676 - val_loss: 0.6122 - learning_rate: 0.0100
# Epoch 31/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7079 - loss: 0.9163 - val_accuracy: 0.7837 - val_loss: 0.6058 - learning_rate: 0.0100
# Epoch 32/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7110 - loss: 0.9068 - val_accuracy: 0.7837 - val_loss: 0.6002 - learning_rate: 0.0100
# Epoch 33/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7112 - loss: 0.9093 - val_accuracy: 0.7842 - val_loss: 0.5945 - learning_rate: 0.0100
# Epoch 34/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7175 - loss: 0.8942 - val_accuracy: 0.7840 - val_loss: 0.5882 - learning_rate: 0.0100
# Epoch 35/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7188 - loss: 0.8826 - val_accuracy: 0.7842 - val_loss: 0.5837 - learning_rate: 0.0100
# Epoch 36/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7160 - loss: 0.8877 - val_accuracy: 0.7844 - val_loss: 0.5784 - learning_rate: 0.0100
# Epoch 37/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7209 - loss: 0.8639 - val_accuracy: 0.7841 - val_loss: 0.5741 - learning_rate: 0.0100
# Epoch 38/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7173 - loss: 0.8721 - val_accuracy: 0.7842 - val_loss: 0.5675 - learning_rate: 0.0100
# Epoch 39/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7230 - loss: 0.8616 - val_accuracy: 0.7845 - val_loss: 0.5624 - learning_rate: 0.0100
# Epoch 40/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7260 - loss: 0.8582 - val_accuracy: 0.7851 - val_loss: 0.5571 - learning_rate: 0.0100
# Epoch 41/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7297 - loss: 0.8422 - val_accuracy: 0.7858 - val_loss: 0.5514 - learning_rate: 0.0100
# Epoch 42/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7300 - loss: 0.8605 - val_accuracy: 0.7867 - val_loss: 0.5465 - learning_rate: 0.0100
# Epoch 43/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7325 - loss: 0.8373 - val_accuracy: 0.7869 - val_loss: 0.5437 - learning_rate: 0.0100
# Epoch 44/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7296 - loss: 0.8349 - val_accuracy: 0.7874 - val_loss: 0.5389 - learning_rate: 0.0100
# Epoch 45/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7351 - loss: 0.8299 - val_accuracy: 0.7871 - val_loss: 0.5361 - learning_rate: 0.0100
# Epoch 46/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7349 - loss: 0.8234 - val_accuracy: 0.7870 - val_loss: 0.5309 - learning_rate: 0.0100
# Epoch 47/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7379 - loss: 0.8132 - val_accuracy: 0.7872 - val_loss: 0.5275 - learning_rate: 0.0100
# Epoch 48/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7408 - loss: 0.8056 - val_accuracy: 0.7874 - val_loss: 0.5246 - learning_rate: 0.0100
# Epoch 49/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7386 - loss: 0.8138 - val_accuracy: 0.7873 - val_loss: 0.5208 - learning_rate: 0.0100
# Epoch 50/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7406 - loss: 0.8071 - val_accuracy: 0.7871 - val_loss: 0.5197 - learning_rate: 0.0100
# Epoch 51/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7429 - loss: 0.7978 - val_accuracy: 0.7872 - val_loss: 0.5137 - learning_rate: 0.0100
# Epoch 52/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7440 - loss: 0.7919 - val_accuracy: 0.7875 - val_loss: 0.5102 - learning_rate: 0.0100
# Epoch 53/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7432 - loss: 0.7957 - val_accuracy: 0.7872 - val_loss: 0.5087 - learning_rate: 0.0100
# Epoch 54/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7501 - loss: 0.7773 - val_accuracy: 0.7871 - val_loss: 0.5053 - learning_rate: 0.0100
# Epoch 55/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7513 - loss: 0.7804 - val_accuracy: 0.7871 - val_loss: 0.5022 - learning_rate: 0.0100
# Epoch 56/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7454 - loss: 0.7923 - val_accuracy: 0.7872 - val_loss: 0.4972 - learning_rate: 0.0100
# Epoch 57/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7560 - loss: 0.7766 - val_accuracy: 0.7872 - val_loss: 0.4970 - learning_rate: 0.0100
# Epoch 58/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7524 - loss: 0.7623 - val_accuracy: 0.7874 - val_loss: 0.4905 - learning_rate: 0.0100
# Epoch 59/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7588 - loss: 0.7662 - val_accuracy: 0.7872 - val_loss: 0.4924 - learning_rate: 0.0100
# Epoch 60/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7545 - loss: 0.7648 - val_accuracy: 0.7874 - val_loss: 0.4844 - learning_rate: 0.0100
# Epoch 61/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7586 - loss: 0.7586 - val_accuracy: 0.7871 - val_loss: 0.4826 - learning_rate: 0.0100
# Epoch 62/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7540 - loss: 0.7555 - val_accuracy: 0.7874 - val_loss: 0.4785 - learning_rate: 0.0100
# Epoch 63/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7587 - loss: 0.7586 - val_accuracy: 0.7874 - val_loss: 0.4757 - learning_rate: 0.0100
# Epoch 64/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7594 - loss: 0.7445 - val_accuracy: 0.7876 - val_loss: 0.4733 - learning_rate: 0.0100
# Epoch 65/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7652 - loss: 0.7413 - val_accuracy: 0.8636 - val_loss: 0.4666 - learning_rate: 0.0100
# Epoch 66/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7590 - loss: 0.7467 - val_accuracy: 0.7875 - val_loss: 0.4698 - learning_rate: 0.0100
# Epoch 67/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7596 - loss: 0.7515 - val_accuracy: 0.8635 - val_loss: 0.4606 - learning_rate: 0.0100
# Epoch 68/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7653 - loss: 0.7388 - val_accuracy: 0.8634 - val_loss: 0.4608 - learning_rate: 0.0100
# Epoch 69/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7673 - loss: 0.7286 - val_accuracy: 0.8635 - val_loss: 0.4575 - learning_rate: 0.0100
# Epoch 70/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7715 - loss: 0.7315 - val_accuracy: 0.8633 - val_loss: 0.4575 - learning_rate: 0.0100
# Epoch 71/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7615 - loss: 0.7287 - val_accuracy: 0.7873 - val_loss: 0.4582 - learning_rate: 0.0100
# Epoch 72/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7685 - loss: 0.7382 - val_accuracy: 0.8636 - val_loss: 0.4494 - learning_rate: 0.0100
# Epoch 73/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7715 - loss: 0.7250 - val_accuracy: 0.8636 - val_loss: 0.4476 - learning_rate: 0.0100
# Epoch 74/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7718 - loss: 0.7163 - val_accuracy: 0.8632 - val_loss: 0.4465 - learning_rate: 0.0100
# Epoch 75/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7744 - loss: 0.7245 - val_accuracy: 0.8635 - val_loss: 0.4395 - learning_rate: 0.0100
# Epoch 76/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7705 - loss: 0.7146 - val_accuracy: 0.8636 - val_loss: 0.4386 - learning_rate: 0.0100
# Epoch 77/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7764 - loss: 0.7150 - val_accuracy: 0.7872 - val_loss: 0.4440 - learning_rate: 0.0100
# Epoch 78/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7796 - loss: 0.7089 - val_accuracy: 0.8635 - val_loss: 0.4333 - learning_rate: 0.0100
# Epoch 79/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7749 - loss: 0.7194 - val_accuracy: 0.8960 - val_loss: 0.4321 - learning_rate: 0.0100
# Epoch 80/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7788 - loss: 0.6985 - val_accuracy: 0.8987 - val_loss: 0.4270 - learning_rate: 0.0100
# Epoch 81/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7765 - loss: 0.7052 - val_accuracy: 0.9045 - val_loss: 0.4244 - learning_rate: 0.0100
# Epoch 82/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7801 - loss: 0.6991 - val_accuracy: 0.9047 - val_loss: 0.4235 - learning_rate: 0.0100
# Epoch 83/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7792 - loss: 0.6957 - val_accuracy: 0.9054 - val_loss: 0.4203 - learning_rate: 0.0100
# Epoch 84/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7854 - loss: 0.6927 - val_accuracy: 0.9048 - val_loss: 0.4209 - learning_rate: 0.0100
# Epoch 85/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7862 - loss: 0.6890 - val_accuracy: 0.9049 - val_loss: 0.4191 - learning_rate: 0.0100
# Epoch 86/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7846 - loss: 0.6887 - val_accuracy: 0.9046 - val_loss: 0.4167 - learning_rate: 0.0100
# Epoch 87/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7869 - loss: 0.6868 - val_accuracy: 0.9050 - val_loss: 0.4087 - learning_rate: 0.0100
# Epoch 88/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7814 - loss: 0.6922 - val_accuracy: 0.9050 - val_loss: 0.4081 - learning_rate: 0.0100
# Epoch 89/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7905 - loss: 0.6771 - val_accuracy: 0.9050 - val_loss: 0.4064 - learning_rate: 0.0100
# Epoch 90/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7882 - loss: 0.6798 - val_accuracy: 0.9050 - val_loss: 0.4055 - learning_rate: 0.0100
# Epoch 91/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7924 - loss: 0.6713 - val_accuracy: 0.9048 - val_loss: 0.4010 - learning_rate: 0.0100
# Epoch 92/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7912 - loss: 0.6759 - val_accuracy: 0.9052 - val_loss: 0.3990 - learning_rate: 0.0100
# Epoch 93/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7908 - loss: 0.6756 - val_accuracy: 0.9049 - val_loss: 0.4007 - learning_rate: 0.0100
# Epoch 94/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7927 - loss: 0.6712 - val_accuracy: 0.9054 - val_loss: 0.3978 - learning_rate: 0.0100
# Epoch 95/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7920 - loss: 0.6643 - val_accuracy: 0.9117 - val_loss: 0.3944 - learning_rate: 0.0100
# Epoch 96/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7905 - loss: 0.6795 - val_accuracy: 0.9061 - val_loss: 0.3977 - learning_rate: 0.0100
# Epoch 97/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7969 - loss: 0.6656 - val_accuracy: 0.9114 - val_loss: 0.3910 - learning_rate: 0.0100
# Epoch 98/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.6655 - val_accuracy: 0.9056 - val_loss: 0.3908 - learning_rate: 0.0100
# Epoch 99/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7966 - loss: 0.6610 - val_accuracy: 0.9129 - val_loss: 0.3868 - learning_rate: 0.0100
# Epoch 100/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7977 - loss: 0.6632 - val_accuracy: 0.9060 - val_loss: 0.3901 - learning_rate: 0.0100
# Epoch 101/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7966 - loss: 0.6566 - val_accuracy: 0.9057 - val_loss: 0.3871 - learning_rate: 0.0100
# Epoch 102/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8025 - loss: 0.6483 - val_accuracy: 0.9054 - val_loss: 0.3842 - learning_rate: 0.0100
# Epoch 103/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8030 - loss: 0.6515 - val_accuracy: 0.9145 - val_loss: 0.3816 - learning_rate: 0.0100
# Epoch 104/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7977 - loss: 0.6528 - val_accuracy: 0.9075 - val_loss: 0.3818 - learning_rate: 0.0100
# Epoch 105/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8012 - loss: 0.6489 - val_accuracy: 0.9137 - val_loss: 0.3784 - learning_rate: 0.0100
# Epoch 106/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8025 - loss: 0.6442 - val_accuracy: 0.9070 - val_loss: 0.3828 - learning_rate: 0.0100
# Epoch 107/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8003 - loss: 0.6482 - val_accuracy: 0.9079 - val_loss: 0.3797 - learning_rate: 0.0100
# Epoch 108/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8067 - loss: 0.6357 - val_accuracy: 0.9077 - val_loss: 0.3772 - learning_rate: 0.0100
# Epoch 109/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8028 - loss: 0.6438 - val_accuracy: 0.9139 - val_loss: 0.3737 - learning_rate: 0.0100
# Epoch 110/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8068 - loss: 0.6393 - val_accuracy: 0.9087 - val_loss: 0.3742 - learning_rate: 0.0100
# Epoch 111/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8068 - loss: 0.6379 - val_accuracy: 0.9104 - val_loss: 0.3731 - learning_rate: 0.0100
# Epoch 112/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8127 - loss: 0.6276 - val_accuracy: 0.9164 - val_loss: 0.3710 - learning_rate: 0.0100
# Epoch 113/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8040 - loss: 0.6348 - val_accuracy: 0.9101 - val_loss: 0.3718 - learning_rate: 0.0100
# Epoch 114/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8078 - loss: 0.6335 - val_accuracy: 0.9167 - val_loss: 0.3663 - learning_rate: 0.0100
# Epoch 115/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8137 - loss: 0.6154 - val_accuracy: 0.9103 - val_loss: 0.3718 - learning_rate: 0.0100
# Epoch 116/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8117 - loss: 0.6281 - val_accuracy: 0.9088 - val_loss: 0.3768 - learning_rate: 0.0100
# Epoch 117/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8094 - loss: 0.6246 - val_accuracy: 0.9165 - val_loss: 0.3657 - learning_rate: 0.0100
# Epoch 118/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8125 - loss: 0.6144 - val_accuracy: 0.9162 - val_loss: 0.3653 - learning_rate: 0.0100
# Epoch 119/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8122 - loss: 0.6321 - val_accuracy: 0.9164 - val_loss: 0.3598 - learning_rate: 0.0100
# Epoch 120/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8086 - loss: 0.6307 - val_accuracy: 0.9163 - val_loss: 0.3626 - learning_rate: 0.0100
# Epoch 121/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8143 - loss: 0.6232 - val_accuracy: 0.9100 - val_loss: 0.3654 - learning_rate: 0.0100
# Epoch 122/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8097 - loss: 0.6256 - val_accuracy: 0.9164 - val_loss: 0.3597 - learning_rate: 0.0100
# Epoch 123/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8092 - loss: 0.6323 - val_accuracy: 0.9166 - val_loss: 0.3603 - learning_rate: 0.0100
# Epoch 124/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8165 - loss: 0.6179 - val_accuracy: 0.9099 - val_loss: 0.3709 - learning_rate: 0.0100
# Epoch 125/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8119 - loss: 0.6202 - val_accuracy: 0.9166 - val_loss: 0.3552 - learning_rate: 0.0100
# Epoch 126/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8153 - loss: 0.6133 - val_accuracy: 0.9166 - val_loss: 0.3548 - learning_rate: 0.0100
# Epoch 127/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8147 - loss: 0.6155 - val_accuracy: 0.9103 - val_loss: 0.3696 - learning_rate: 0.0100
# Epoch 128/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8167 - loss: 0.6070 - val_accuracy: 0.9167 - val_loss: 0.3526 - learning_rate: 0.0100
# Epoch 129/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8146 - loss: 0.6138 - val_accuracy: 0.9168 - val_loss: 0.3532 - learning_rate: 0.0100
# Epoch 130/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8190 - loss: 0.6123 - val_accuracy: 0.9165 - val_loss: 0.3575 - learning_rate: 0.0100
# Epoch 131/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8185 - loss: 0.6084 - val_accuracy: 0.9166 - val_loss: 0.3550 - learning_rate: 0.0100
# Epoch 132/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8201 - loss: 0.5996 - val_accuracy: 0.9165 - val_loss: 0.3504 - learning_rate: 0.0100
# Epoch 133/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8164 - loss: 0.6140 - val_accuracy: 0.9104 - val_loss: 0.3564 - learning_rate: 0.0100
# Epoch 134/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8197 - loss: 0.6074 - val_accuracy: 0.9167 - val_loss: 0.3511 - learning_rate: 0.0100
# Epoch 135/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8194 - loss: 0.5959 - val_accuracy: 0.9169 - val_loss: 0.3485 - learning_rate: 0.0100
# Epoch 136/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8198 - loss: 0.6078 - val_accuracy: 0.9170 - val_loss: 0.3468 - learning_rate: 0.0100
# Epoch 137/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8196 - loss: 0.6074 - val_accuracy: 0.9167 - val_loss: 0.3476 - learning_rate: 0.0100
# Epoch 138/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8213 - loss: 0.5984 - val_accuracy: 0.9170 - val_loss: 0.3464 - learning_rate: 0.0100
# Epoch 139/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8233 - loss: 0.5949 - val_accuracy: 0.9168 - val_loss: 0.3515 - learning_rate: 0.0100
# Epoch 140/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8215 - loss: 0.6006 - val_accuracy: 0.9167 - val_loss: 0.3442 - learning_rate: 0.0100
# Epoch 141/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8232 - loss: 0.5899 - val_accuracy: 0.9167 - val_loss: 0.3465 - learning_rate: 0.0100
# Epoch 142/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8219 - loss: 0.5939 - val_accuracy: 0.9170 - val_loss: 0.3448 - learning_rate: 0.0100
# Epoch 143/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8250 - loss: 0.5857 - val_accuracy: 0.9170 - val_loss: 0.3433 - learning_rate: 0.0100
# Epoch 144/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8213 - loss: 0.5965 - val_accuracy: 0.9170 - val_loss: 0.3456 - learning_rate: 0.0100
# Epoch 145/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8285 - loss: 0.5909 - val_accuracy: 0.9164 - val_loss: 0.3437 - learning_rate: 0.0100
# Epoch 146/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8245 - loss: 0.5981 - val_accuracy: 0.9170 - val_loss: 0.3453 - learning_rate: 0.0100
# Epoch 147/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8240 - loss: 0.5865 - val_accuracy: 0.9169 - val_loss: 0.3405 - learning_rate: 0.0100
# Epoch 148/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8274 - loss: 0.5888 - val_accuracy: 0.9170 - val_loss: 0.3398 - learning_rate: 0.0100
# Epoch 149/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8262 - loss: 0.5867 - val_accuracy: 0.9169 - val_loss: 0.3399 - learning_rate: 0.0100
# Epoch 150/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8260 - loss: 0.5871 - val_accuracy: 0.9170 - val_loss: 0.3401 - learning_rate: 0.0100
# Epoch 151/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8297 - loss: 0.5797 - val_accuracy: 0.9170 - val_loss: 0.3412 - learning_rate: 0.0100
# Epoch 152/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8247 - loss: 0.5965 - val_accuracy: 0.9168 - val_loss: 0.3384 - learning_rate: 0.0100
# Epoch 153/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8285 - loss: 0.5751 - val_accuracy: 0.9170 - val_loss: 0.3390 - learning_rate: 0.0100
# Epoch 154/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8281 - loss: 0.5806 - val_accuracy: 0.9165 - val_loss: 0.3379 - learning_rate: 0.0100
# Epoch 155/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8248 - loss: 0.5862 - val_accuracy: 0.9168 - val_loss: 0.3379 - learning_rate: 0.0100
# Epoch 156/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8328 - loss: 0.5727 - val_accuracy: 0.9167 - val_loss: 0.3416 - learning_rate: 0.0100
# Epoch 157/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8306 - loss: 0.5672 - val_accuracy: 0.9166 - val_loss: 0.3443 - learning_rate: 0.0100
# Epoch 158/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8301 - loss: 0.5819 - val_accuracy: 0.9166 - val_loss: 0.3404 - learning_rate: 0.0100
# Epoch 159/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8277 - loss: 0.5853 - val_accuracy: 0.9168 - val_loss: 0.3363 - learning_rate: 0.0100
# Epoch 160/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8322 - loss: 0.5688 - val_accuracy: 0.9169 - val_loss: 0.3401 - learning_rate: 0.0100
# Epoch 161/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8313 - loss: 0.5757 - val_accuracy: 0.9169 - val_loss: 0.3385 - learning_rate: 0.0100
# Epoch 162/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8317 - loss: 0.5682 - val_accuracy: 0.9169 - val_loss: 0.3354 - learning_rate: 0.0100
# Epoch 163/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8371 - loss: 0.5658 - val_accuracy: 0.9106 - val_loss: 0.3479 - learning_rate: 0.0100
# Epoch 164/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8346 - loss: 0.5622 - val_accuracy: 0.9168 - val_loss: 0.3340 - learning_rate: 0.0100
# Epoch 165/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8303 - loss: 0.5750 - val_accuracy: 0.9168 - val_loss: 0.3384 - learning_rate: 0.0100
# Epoch 166/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8304 - loss: 0.5737 - val_accuracy: 0.9170 - val_loss: 0.3400 - learning_rate: 0.0100
# Epoch 167/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8333 - loss: 0.5644 - val_accuracy: 0.9168 - val_loss: 0.3384 - learning_rate: 0.0100
# Epoch 168/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8329 - loss: 0.5630 - val_accuracy: 0.9170 - val_loss: 0.3323 - learning_rate: 0.0100
# Epoch 169/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8332 - loss: 0.5657 - val_accuracy: 0.9168 - val_loss: 0.3326 - learning_rate: 0.0100
# Epoch 170/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8378 - loss: 0.5606 - val_accuracy: 0.9168 - val_loss: 0.3361 - learning_rate: 0.0100
# Epoch 171/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8343 - loss: 0.5651 - val_accuracy: 0.9165 - val_loss: 0.3371 - learning_rate: 0.0100
# Epoch 172/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8394 - loss: 0.5515 - val_accuracy: 0.9107 - val_loss: 0.3441 - learning_rate: 0.0100
# Epoch 173/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8335 - loss: 0.5746 - val_accuracy: 0.9168 - val_loss: 0.3312 - learning_rate: 0.0100
# Epoch 174/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8394 - loss: 0.5587 - val_accuracy: 0.9170 - val_loss: 0.3303 - learning_rate: 0.0100
# Epoch 175/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8364 - loss: 0.5534 - val_accuracy: 0.9169 - val_loss: 0.3340 - learning_rate: 0.0100
# Epoch 176/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8322 - loss: 0.5625 - val_accuracy: 0.9169 - val_loss: 0.3307 - learning_rate: 0.0100
# Epoch 177/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8350 - loss: 0.5531 - val_accuracy: 0.9171 - val_loss: 0.3298 - learning_rate: 0.0100
# Epoch 178/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8371 - loss: 0.5517 - val_accuracy: 0.9168 - val_loss: 0.3292 - learning_rate: 0.0100
# Epoch 179/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8384 - loss: 0.5566 - val_accuracy: 0.9171 - val_loss: 0.3291 - learning_rate: 0.0100
# Epoch 180/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8407 - loss: 0.5498 - val_accuracy: 0.9170 - val_loss: 0.3313 - learning_rate: 0.0100
# Epoch 181/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8369 - loss: 0.5659 - val_accuracy: 0.9171 - val_loss: 0.3282 - learning_rate: 0.0100
# Epoch 182/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8394 - loss: 0.5482 - val_accuracy: 0.9173 - val_loss: 0.3291 - learning_rate: 0.0100
# Epoch 183/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8369 - loss: 0.5637 - val_accuracy: 0.9169 - val_loss: 0.3286 - learning_rate: 0.0100
# Epoch 184/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8337 - loss: 0.5573 - val_accuracy: 0.9170 - val_loss: 0.3328 - learning_rate: 0.0100
# Epoch 185/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8405 - loss: 0.5430 - val_accuracy: 0.9171 - val_loss: 0.3326 - learning_rate: 0.0100
# Epoch 186/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8313 - loss: 0.5565 - val_accuracy: 0.9170 - val_loss: 0.3276 - learning_rate: 0.0100
# Epoch 187/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8377 - loss: 0.5577 - val_accuracy: 0.9170 - val_loss: 0.3269 - learning_rate: 0.0100
# Epoch 188/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8417 - loss: 0.5435 - val_accuracy: 0.9170 - val_loss: 0.3303 - learning_rate: 0.0100
# Epoch 189/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8412 - loss: 0.5436 - val_accuracy: 0.9170 - val_loss: 0.3292 - learning_rate: 0.0100
# Epoch 190/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8368 - loss: 0.5587 - val_accuracy: 0.9170 - val_loss: 0.3274 - learning_rate: 0.0100
# Epoch 191/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8396 - loss: 0.5477 - val_accuracy: 0.9170 - val_loss: 0.3258 - learning_rate: 0.0100
# Epoch 192/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8396 - loss: 0.5468 - val_accuracy: 0.9170 - val_loss: 0.3261 - learning_rate: 0.0100
# Epoch 193/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.5498 - val_accuracy: 0.9174 - val_loss: 0.3258 - learning_rate: 0.0100
# Epoch 194/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8406 - loss: 0.5479 - val_accuracy: 0.9171 - val_loss: 0.3335 - learning_rate: 0.0100
# Epoch 195/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8364 - loss: 0.5653
# Epoch 195: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8364 - loss: 0.5652 - val_accuracy: 0.9169 - val_loss: 0.3314 - learning_rate: 0.0100
# Epoch 196/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8431 - loss: 0.5474 - val_accuracy: 0.9171 - val_loss: 0.3270 - learning_rate: 0.0050
# Epoch 197/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8397 - loss: 0.5594 - val_accuracy: 0.9171 - val_loss: 0.3262 - learning_rate: 0.0050
# Epoch 198/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8457 - loss: 0.5338 - val_accuracy: 0.9170 - val_loss: 0.3288 - learning_rate: 0.0050
# Epoch 199/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8391 - loss: 0.5452 - val_accuracy: 0.9171 - val_loss: 0.3255 - learning_rate: 0.0050
# Epoch 200/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8403 - loss: 0.5575 - val_accuracy: 0.9170 - val_loss: 0.3247 - learning_rate: 0.0050
# Epoch 201/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8370 - loss: 0.5449 - val_accuracy: 0.9172 - val_loss: 0.3270 - learning_rate: 0.0050
# Epoch 202/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8434 - loss: 0.5410 - val_accuracy: 0.9170 - val_loss: 0.3263 - learning_rate: 0.0050
# Epoch 203/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8380 - loss: 0.5499 - val_accuracy: 0.9170 - val_loss: 0.3248 - learning_rate: 0.0050
# Epoch 204/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8451 - loss: 0.5402 - val_accuracy: 0.9170 - val_loss: 0.3249 - learning_rate: 0.0050
# Epoch 205/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8421 - loss: 0.5489 - val_accuracy: 0.9172 - val_loss: 0.3242 - learning_rate: 0.0050
# Epoch 206/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8440 - loss: 0.5429 - val_accuracy: 0.9172 - val_loss: 0.3256 - learning_rate: 0.0050
# Epoch 207/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8396 - loss: 0.5508 - val_accuracy: 0.9172 - val_loss: 0.3237 - learning_rate: 0.0050
# Epoch 208/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8413 - loss: 0.5335 - val_accuracy: 0.9170 - val_loss: 0.3250 - learning_rate: 0.0050
# Epoch 209/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8438 - loss: 0.5439 - val_accuracy: 0.9170 - val_loss: 0.3307 - learning_rate: 0.0050
# Epoch 210/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8416 - loss: 0.5401 - val_accuracy: 0.9172 - val_loss: 0.3235 - learning_rate: 0.0050
# Epoch 211/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8422 - loss: 0.5424 - val_accuracy: 0.9171 - val_loss: 0.3248 - learning_rate: 0.0050
# Epoch 212/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8471 - loss: 0.5294 - val_accuracy: 0.9173 - val_loss: 0.3246 - learning_rate: 0.0050
# Epoch 213/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8416 - loss: 0.5424 - val_accuracy: 0.9173 - val_loss: 0.3223 - learning_rate: 0.0050
# Epoch 214/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8412 - loss: 0.5464 - val_accuracy: 0.9171 - val_loss: 0.3236 - learning_rate: 0.0050
# Epoch 215/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8481 - loss: 0.5292 - val_accuracy: 0.9173 - val_loss: 0.3231 - learning_rate: 0.0050
# Epoch 216/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8442 - loss: 0.5420 - val_accuracy: 0.9175 - val_loss: 0.3219 - learning_rate: 0.0050
# Epoch 217/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8462 - loss: 0.5363 - val_accuracy: 0.9174 - val_loss: 0.3239 - learning_rate: 0.0050
# Epoch 218/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8452 - loss: 0.5253 - val_accuracy: 0.9178 - val_loss: 0.3221 - learning_rate: 0.0050
# Epoch 219/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8435 - loss: 0.5407 - val_accuracy: 0.9171 - val_loss: 0.3225 - learning_rate: 0.0050
# Epoch 220/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8406 - loss: 0.5468 - val_accuracy: 0.9172 - val_loss: 0.3209 - learning_rate: 0.0050
# Epoch 221/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8440 - loss: 0.5441 - val_accuracy: 0.9173 - val_loss: 0.3214 - learning_rate: 0.0050
# Epoch 222/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8437 - loss: 0.5369 - val_accuracy: 0.9172 - val_loss: 0.3237 - learning_rate: 0.0050
# Epoch 223/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8426 - loss: 0.5441 - val_accuracy: 0.9172 - val_loss: 0.3227 - learning_rate: 0.0050
# Epoch 224/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8441 - loss: 0.5361 - val_accuracy: 0.9175 - val_loss: 0.3212 - learning_rate: 0.0050
# Epoch 225/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8447 - loss: 0.5367 - val_accuracy: 0.9172 - val_loss: 0.3238 - learning_rate: 0.0050
# Epoch 226/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8427 - loss: 0.5340 - val_accuracy: 0.9175 - val_loss: 0.3230 - learning_rate: 0.0050
# Epoch 227/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8424 - loss: 0.5363 - val_accuracy: 0.9173 - val_loss: 0.3224 - learning_rate: 0.0050
# Epoch 228/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8428 - loss: 0.5336 - val_accuracy: 0.9175 - val_loss: 0.3222 - learning_rate: 0.0050
# Epoch 229/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8460 - loss: 0.5378 - val_accuracy: 0.9171 - val_loss: 0.3222 - learning_rate: 0.0050
# Epoch 230/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8434 - loss: 0.5380 - val_accuracy: 0.9174 - val_loss: 0.3219 - learning_rate: 0.0050
# Epoch 231/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8435 - loss: 0.5338 - val_accuracy: 0.9175 - val_loss: 0.3203 - learning_rate: 0.0050
# Epoch 232/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8429 - loss: 0.5448 - val_accuracy: 0.9175 - val_loss: 0.3204 - learning_rate: 0.0050
# Epoch 233/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8438 - loss: 0.5433 - val_accuracy: 0.9173 - val_loss: 0.3213 - learning_rate: 0.0050
# Epoch 234/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8419 - loss: 0.5350 - val_accuracy: 0.9171 - val_loss: 0.3210 - learning_rate: 0.0050
# Epoch 235/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8455 - loss: 0.5347 - val_accuracy: 0.9172 - val_loss: 0.3217 - learning_rate: 0.0050
# Epoch 236/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8471 - loss: 0.5243 - val_accuracy: 0.9175 - val_loss: 0.3217 - learning_rate: 0.0050
# Epoch 237/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8484 - loss: 0.5274 - val_accuracy: 0.9173 - val_loss: 0.3219 - learning_rate: 0.0050
# Epoch 238/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8450 - loss: 0.5378 - val_accuracy: 0.9171 - val_loss: 0.3202 - learning_rate: 0.0050
# Epoch 239/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8459 - loss: 0.5319 - val_accuracy: 0.9173 - val_loss: 0.3325 - learning_rate: 0.0050
# Epoch 240/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8411 - loss: 0.5377 - val_accuracy: 0.9175 - val_loss: 0.3214 - learning_rate: 0.0050
# Epoch 241/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8422 - loss: 0.5442 - val_accuracy: 0.9175 - val_loss: 0.3198 - learning_rate: 0.0050
# Epoch 242/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8451 - loss: 0.5392 - val_accuracy: 0.9175 - val_loss: 0.3214 - learning_rate: 0.0050
# Epoch 243/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8467 - loss: 0.5310 - val_accuracy: 0.9175 - val_loss: 0.3227 - learning_rate: 0.0050
# Epoch 244/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8507 - loss: 0.5225 - val_accuracy: 0.9179 - val_loss: 0.3202 - learning_rate: 0.0050
# Epoch 245/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8444 - loss: 0.5384 - val_accuracy: 0.9173 - val_loss: 0.3204 - learning_rate: 0.0050
# Epoch 246/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8484 - loss: 0.5242 - val_accuracy: 0.9173 - val_loss: 0.3198 - learning_rate: 0.0050
# Epoch 247/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8491 - loss: 0.5409 - val_accuracy: 0.9177 - val_loss: 0.3193 - learning_rate: 0.0050
# Epoch 248/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8424 - loss: 0.5330 - val_accuracy: 0.9172 - val_loss: 0.3232 - learning_rate: 0.0050
# Epoch 249/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8475 - loss: 0.5278 - val_accuracy: 0.9174 - val_loss: 0.3210 - learning_rate: 0.0050
# Epoch 250/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8485 - loss: 0.5346 - val_accuracy: 0.9175 - val_loss: 0.3199 - learning_rate: 0.0050
# Epoch 251/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8474 - loss: 0.5301 - val_accuracy: 0.9174 - val_loss: 0.3204 - learning_rate: 0.0050
# Epoch 252/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8491 - loss: 0.5261 - val_accuracy: 0.9177 - val_loss: 0.3191 - learning_rate: 0.0050
# Epoch 253/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8508 - loss: 0.5297 - val_accuracy: 0.9175 - val_loss: 0.3185 - learning_rate: 0.0050
# Epoch 254/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8502 - loss: 0.5162 - val_accuracy: 0.9178 - val_loss: 0.3182 - learning_rate: 0.0050
# Epoch 255/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8491 - loss: 0.5274 - val_accuracy: 0.9179 - val_loss: 0.3201 - learning_rate: 0.0050
# Epoch 256/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8427 - loss: 0.5318 - val_accuracy: 0.9172 - val_loss: 0.3228 - learning_rate: 0.0050
# Epoch 257/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8480 - loss: 0.5308 - val_accuracy: 0.9176 - val_loss: 0.3188 - learning_rate: 0.0050
# Epoch 258/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8455 - loss: 0.5301 - val_accuracy: 0.9175 - val_loss: 0.3189 - learning_rate: 0.0050
# Epoch 259/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8456 - loss: 0.5324 - val_accuracy: 0.9180 - val_loss: 0.3191 - learning_rate: 0.0050
# Epoch 260/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8441 - loss: 0.5329 - val_accuracy: 0.9174 - val_loss: 0.3220 - learning_rate: 0.0050
# Epoch 261/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8434 - loss: 0.5326 - val_accuracy: 0.9177 - val_loss: 0.3193 - learning_rate: 0.0050
# Epoch 262/300
# 35/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8440 - loss: 0.5363
# Epoch 262: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8452 - loss: 0.5335 - val_accuracy: 0.9180 - val_loss: 0.3187 - learning_rate: 0.0050
# Epoch 263/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8442 - loss: 0.5315 - val_accuracy: 0.9176 - val_loss: 0.3188 - learning_rate: 0.0025
# Epoch 264/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8471 - loss: 0.5269 - val_accuracy: 0.9177 - val_loss: 0.3194 - learning_rate: 0.0025
# Epoch 265/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8491 - loss: 0.5140 - val_accuracy: 0.9175 - val_loss: 0.3198 - learning_rate: 0.0025
# Epoch 266/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8471 - loss: 0.5326 - val_accuracy: 0.9176 - val_loss: 0.3188 - learning_rate: 0.0025
# Epoch 267/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8489 - loss: 0.5299 - val_accuracy: 0.9177 - val_loss: 0.3202 - learning_rate: 0.0025
# Epoch 268/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8490 - loss: 0.5228 - val_accuracy: 0.9174 - val_loss: 0.3200 - learning_rate: 0.0025
# Epoch 269/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8485 - loss: 0.5245 - val_accuracy: 0.9180 - val_loss: 0.3179 - learning_rate: 0.0025
# Epoch 270/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8450 - loss: 0.5357 - val_accuracy: 0.9174 - val_loss: 0.3191 - learning_rate: 0.0025
# Epoch 271/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8523 - loss: 0.5207 - val_accuracy: 0.9176 - val_loss: 0.3196 - learning_rate: 0.0025
# Epoch 272/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8471 - loss: 0.5239 - val_accuracy: 0.9173 - val_loss: 0.3205 - learning_rate: 0.0025
# Epoch 273/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8517 - loss: 0.5180 - val_accuracy: 0.9181 - val_loss: 0.3182 - learning_rate: 0.0025
# Epoch 274/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8454 - loss: 0.5237 - val_accuracy: 0.9175 - val_loss: 0.3186 - learning_rate: 0.0025
# Epoch 275/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8479 - loss: 0.5278 - val_accuracy: 0.9176 - val_loss: 0.3188 - learning_rate: 0.0025
# Epoch 276/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8497 - loss: 0.5281 - val_accuracy: 0.9174 - val_loss: 0.3195 - learning_rate: 0.0025
# Epoch 277/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8510 - loss: 0.5192 - val_accuracy: 0.9176 - val_loss: 0.3193 - learning_rate: 0.0025
# Epoch 278/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8465 - loss: 0.5321 - val_accuracy: 0.9181 - val_loss: 0.3180 - learning_rate: 0.0025
# Epoch 279/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8518 - loss: 0.5172 - val_accuracy: 0.9181 - val_loss: 0.3180 - learning_rate: 0.0025
# Epoch 280/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8518 - loss: 0.5269 - val_accuracy: 0.9181 - val_loss: 0.3180 - learning_rate: 0.0025
# Epoch 281/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8501 - loss: 0.5260 - val_accuracy: 0.9175 - val_loss: 0.3214 - learning_rate: 0.0025
# Epoch 282/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8501 - loss: 0.5131 - val_accuracy: 0.9176 - val_loss: 0.3198 - learning_rate: 0.0025
# Epoch 283/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8482 - loss: 0.5278 - val_accuracy: 0.9181 - val_loss: 0.3179 - learning_rate: 0.0025
# Epoch 284/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8467 - loss: 0.5269 - val_accuracy: 0.9185 - val_loss: 0.3176 - learning_rate: 0.0025
# Epoch 285/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8457 - loss: 0.5312 - val_accuracy: 0.9179 - val_loss: 0.3191 - learning_rate: 0.0025
# Epoch 286/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8465 - loss: 0.5288 - val_accuracy: 0.9181 - val_loss: 0.3173 - learning_rate: 0.0025
# Epoch 287/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8485 - loss: 0.5289 - val_accuracy: 0.9177 - val_loss: 0.3187 - learning_rate: 0.0025
# Epoch 288/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8523 - loss: 0.5217 - val_accuracy: 0.9184 - val_loss: 0.3176 - learning_rate: 0.0025
# Epoch 289/300
# 69/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8519 - loss: 0.5090
# Epoch 289: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8518 - loss: 0.5093 - val_accuracy: 0.9176 - val_loss: 0.3192 - learning_rate: 0.0025
# Epoch 290/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8471 - loss: 0.5369 - val_accuracy: 0.9178 - val_loss: 0.3185 - learning_rate: 0.0012
# Epoch 291/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8473 - loss: 0.5134 - val_accuracy: 0.9181 - val_loss: 0.3178 - learning_rate: 0.0012
# Epoch 292/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8485 - loss: 0.5269 - val_accuracy: 0.9180 - val_loss: 0.3180 - learning_rate: 0.0012
# Epoch 293/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8539 - loss: 0.5076 - val_accuracy: 0.9178 - val_loss: 0.3181 - learning_rate: 0.0012
# Epoch 294/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8492 - loss: 0.5244 - val_accuracy: 0.9183 - val_loss: 0.3178 - learning_rate: 0.0012
# Epoch 295/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8523 - loss: 0.5133 - val_accuracy: 0.9181 - val_loss: 0.3183 - learning_rate: 0.0012
# Epoch 296/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8496 - loss: 0.5309 - val_accuracy: 0.9177 - val_loss: 0.3184 - learning_rate: 0.0012
# Epoch 297/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8509 - loss: 0.5121 - val_accuracy: 0.9177 - val_loss: 0.3183 - learning_rate: 0.0012
# Epoch 298/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8491 - loss: 0.5288 - val_accuracy: 0.9176 - val_loss: 0.3184 - learning_rate: 0.0012
# Epoch 299/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8477 - loss: 0.5188
# Epoch 299: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8478 - loss: 0.5189 - val_accuracy: 0.9177 - val_loss: 0.3185 - learning_rate: 0.0012
# Epoch 300/300
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8495 - loss: 0.5276 - val_accuracy: 0.9177 - val_loss: 0.3185 - learning_rate: 6.2500e-04

# %%
# Load the best saved model
best_model = load_model('Saved-Models/Farm-Flow_DNN-Deep-Neural-Network_Model.keras')

# Evaluate the best saved model
score = best_model.evaluate(X_val, y_val)
print('')
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - accuracy: 0.9174 - loss: 0.3262
#
# Test loss: 0.328858882188797
# Test accuracy: 0.9173160791397095

# %%
fig, ax = plt.subplots(figsize=(20, 16))

ax.plot(history.history['loss'], label='train')
ax.plot(history.history['val_loss'], label='test')
ax.set_title('Model Loss')
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch')
ax.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %% [markdown]
# ## Results

# %%
pred = model.predict(X_val)
# Out:
# 494/494 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step

# %%
import numpy as np

# Random state definition
random_state=42
np.random.seed(random_state)

# %%
from sklearn import metrics

# Metrics for the classification
def compute_metrics(pred, y_val):
    predict_classes = np.argmax(pred, axis=1)
    
    # If y_val is one-hot encoded, convert it to class labels
    if y_val.ndim > 1:
        y_val = np.argmax(y_val, axis=1)

    correct = metrics.accuracy_score(y_val, predict_classes)
    print(f"Accuracy: {correct}")
    
    recall = metrics.recall_score(y_val, predict_classes, average='weighted')    
    print(f"Recall: {recall}")
       
    precision = metrics.precision_score(y_val, predict_classes, average='weighted')
    print(f"Precision: {precision}")
    
    f1score = metrics.f1_score(y_val, predict_classes, average='weighted')
    print(f"F1-Score: {f1score}")

# %%
compute_metrics(pred, y_val)
# Out:
# Accuracy: 0.9165557878730279
# Recall: 0.9165557878730279
# Precision: 0.8924862613109408
# F1-Score: 0.8994138017805986
# /home/ivoafonsobispo/miniconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
